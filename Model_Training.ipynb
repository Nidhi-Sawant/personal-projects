# %%
from google.colab import drive
drive.mount('/content/drive') #connecting google drive
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/Flask-Knee
# Out:
# /content/drive/MyDrive/Flask-Knee

# %%
# %tensorflow_version 2.x
# Out:
# Colab only includes TensorFlow 2.x; %tensorflow_version has no effect.

# %%
import tensorflow
print(tensorflow.__version__)
# Out:
# 2.15.0

# %% [markdown]
# #Data Preprocessing

# %%
import cv2,os
data_path='/content/drive/MyDrive/Flask-Knee/MedicalExpert-I/'
categories=os.listdir(data_path)
labels=[i for i in range(len(categories))]

label_dict=dict(zip(categories,labels)) #empty dictionary
print(label_dict)
print(categories)
print(labels)
# Out:
# {'Severe': 0, 'Mild': 1, 'Normal': 2, 'Moderate': 3, 'Doubtful': 4}
# ['Severe', 'Mild', 'Normal', 'Moderate', 'Doubtful']
# [0, 1, 2, 3, 4]

# %%
img_size=256
data=[]
label=[]

for category in categories:
    folder_path=os.path.join(data_path,category)
    img_names=os.listdir(folder_path)

    for img_name in img_names:
        img_path=os.path.join(folder_path,img_name)
        img=cv2.imread(img_path)
        try:
            gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
            resized=cv2.resize(gray,(img_size,img_size))
            #resizing the image  into 256 x 256
            data.append(resized)
            label.append(label_dict[category])
            #appending the image and the label(categorized) into the list (dataset)
        except Exception as e:
            print('Exception:',e)
            #if any exception rasied, the exception will be printed here. And pass to the next image

# %% [markdown]
# # Rescale and assign  catagorical labels

# %%
# !pip install utils
# Out:
# Collecting utils
#   Downloading utils-1.0.2.tar.gz (13 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: utils
#   Building wheel for utils (setup.py) ... done
#   Created wheel for utils: filename=utils-1.0.2-py2.py3-none-any.whl size=13906 sha256=5a4d0382b5d3bacabc8053599b189442f6e26efd5dc8ded4f90dd5bd02c71401
#   Stored in directory: /root/.cache/pip/wheels/b8/39/f5/9d0ca31dba85773ececf0a7f5469f18810e1c8a8ed9da28ca7
# Successfully built utils
# Installing collected packages: utils
# Successfully installed utils-1.0.2

# %%
import utils

# !pip install keras
# Out:
# Requirement already satisfied: keras in /usr/local/lib/python3.10/dist-packages (2.15.0)

# %%
from tensorflow.keras.utils import to_categorical

# %%
new_label = to_categorical(label)

# %%
# !pip show keras
# Out:
# Name: keras
# Version: 2.15.0
# Summary: Deep learning for humans.
# Home-page: https://keras.io/
# Author: Keras team
# Author-email: keras-users@googlegroups.com
# License: Apache 2.0
# Location: /usr/local/lib/python3.10/dist-packages
# Requires:
# Required-by: tensorflow

# %%
import numpy as np
data=np.array(data)/255.0
data=np.reshape(data,(data.shape[0],img_size,img_size,1))
label=np.array(label)
from keras import utils
new_label=utils.to_categorical(label)

# %%
new_label.shape
# Out:
# (1650, 5)

# %% [markdown]
# #CNN Model

# %%
data.shape
# Out:
# (1650, 256, 256, 1)

# %%
data.shape[1:]
# Out:
# (256, 256, 1)

# %%
from keras.models import Sequential
from keras.layers import Dense,Activation,Flatten,Dropout
from keras.layers import Conv2D,MaxPooling2D
from keras.callbacks import ModelCheckpoint

model=Sequential()

model.add(Conv2D(128,(3,3),input_shape=data.shape[1:]))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
#The first CNN layer followed by Relu and MaxPooling layers

model.add(Conv2D(64,(3,3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
#The second convolution layer followed by Relu and MaxPooling layers

model.add(Conv2D(32,(3,3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
#The thrid convolution layer followed by Relu and MaxPooling layers

model.add(Flatten())
#Flatten layer to stack the output convolutions from 3rd convolution layer
model.add(Dropout(0.2))

model.add(Dense(128,activation='relu'))
#Dense layer of 128 neurons

model.add(Dropout(0.1))
model.add(Dense(64,activation='relu'))
#Dense layer of 64 neurons

model.add(Dropout(0.1))
model.add(Dense(64,activation='relu'))
#Dense layer of 64 neurons
#added

model.add(Dense(5,activation='softmax'))
#The Final layer with two outputs for two categories

model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
learning_rate = 0.01

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 254, 254, 128)     1280
#
#  activation (Activation)     (None, 254, 254, 128)     0
#
#  max_pooling2d (MaxPooling2  (None, 127, 127, 128)     0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 125, 125, 64)      73792
#
#  activation_1 (Activation)   (None, 125, 125, 64)      0
#
#  max_pooling2d_1 (MaxPoolin  (None, 62, 62, 64)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 60, 60, 32)        18464
#
#  activation_2 (Activation)   (None, 60, 60, 32)        0
#
#  max_pooling2d_2 (MaxPoolin  (None, 30, 30, 32)        0
#  g2D)
#
#  flatten (Flatten)           (None, 28800)             0
#
#  dropout (Dropout)           (None, 28800)             0
#
#  dense (Dense)               (None, 128)               3686528
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  dense_2 (Dense)             (None, 64)                4160
#
#  dense_3 (Dense)             (None, 5)                 325
#
# =================================================================
# Total params: 3792805 (14.47 MB)
# Trainable params: 3792805 (14.47 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# # Splitting data into traning and testing

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(data,new_label,test_size=0.1)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,10))
for i in range(20):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(np.squeeze(x_test[i]))
    plt.xlabel(categories[np.argmax(y_test[i])])
plt.show()

# %%
history=model.fit(x_train,y_train,epochs=100,validation_split=0.2)
# Out:
# Epoch 1/100
# 38/38 [==============================] - 25s 230ms/step - loss: 1.5451 - accuracy: 0.2862 - val_loss: 1.5220 - val_accuracy: 0.3131
# Epoch 2/100
# 38/38 [==============================] - 6s 147ms/step - loss: 1.5008 - accuracy: 0.3308 - val_loss: 1.5185 - val_accuracy: 0.3434
# Epoch 3/100
# 38/38 [==============================] - 5s 125ms/step - loss: 1.4726 - accuracy: 0.3510 - val_loss: 1.4636 - val_accuracy: 0.3569
# Epoch 4/100
# 38/38 [==============================] - 5s 119ms/step - loss: 1.4660 - accuracy: 0.3460 - val_loss: 1.4824 - val_accuracy: 0.3502
# Epoch 5/100
# 38/38 [==============================] - 5s 121ms/step - loss: 1.4320 - accuracy: 0.3678 - val_loss: 1.4593 - val_accuracy: 0.3805
# Epoch 6/100
# 38/38 [==============================] - 5s 121ms/step - loss: 1.4205 - accuracy: 0.3628 - val_loss: 1.4539 - val_accuracy: 0.3569
# Epoch 7/100
# 38/38 [==============================] - 5s 119ms/step - loss: 1.3763 - accuracy: 0.3830 - val_loss: 1.4244 - val_accuracy: 0.4040
# Epoch 8/100
# 38/38 [==============================] - 5s 122ms/step - loss: 1.3476 - accuracy: 0.4057 - val_loss: 1.4391 - val_accuracy: 0.4040
# Epoch 9/100
# 38/38 [==============================] - 5s 122ms/step - loss: 1.3246 - accuracy: 0.4099 - val_loss: 1.4035 - val_accuracy: 0.4108
# Epoch 10/100
# 38/38 [==============================] - 5s 120ms/step - loss: 1.2903 - accuracy: 0.4327 - val_loss: 1.4420 - val_accuracy: 0.4141
# Epoch 11/100
# 38/38 [==============================] - 5s 123ms/step - loss: 1.2922 - accuracy: 0.4394 - val_loss: 1.3969 - val_accuracy: 0.4242
# Epoch 12/100
# 38/38 [==============================] - 5s 120ms/step - loss: 1.2334 - accuracy: 0.4747 - val_loss: 1.4022 - val_accuracy: 0.4276
# Epoch 13/100
# 38/38 [==============================] - 5s 120ms/step - loss: 1.1799 - accuracy: 0.5000 - val_loss: 1.3501 - val_accuracy: 0.4646
# Epoch 14/100
# 38/38 [==============================] - 5s 123ms/step - loss: 1.1692 - accuracy: 0.5194 - val_loss: 1.3726 - val_accuracy: 0.4411
# Epoch 15/100
# 38/38 [==============================] - 5s 121ms/step - loss: 1.0998 - accuracy: 0.5354 - val_loss: 1.3845 - val_accuracy: 0.4512
# Epoch 16/100
# 38/38 [==============================] - 5s 122ms/step - loss: 1.0494 - accuracy: 0.5623 - val_loss: 1.4561 - val_accuracy: 0.4276
# Epoch 17/100
# 38/38 [==============================] - 5s 124ms/step - loss: 1.0209 - accuracy: 0.5783 - val_loss: 1.4440 - val_accuracy: 0.4478
# Epoch 18/100
# 38/38 [==============================] - 5s 121ms/step - loss: 0.9592 - accuracy: 0.6010 - val_loss: 1.5066 - val_accuracy: 0.4545
# Epoch 19/100
# 38/38 [==============================] - 5s 122ms/step - loss: 0.8927 - accuracy: 0.6465 - val_loss: 1.3658 - val_accuracy: 0.5118
# Epoch 20/100
# 38/38 [==============================] - 5s 125ms/step - loss: 0.8040 - accuracy: 0.6843 - val_loss: 1.4809 - val_accuracy: 0.5219
# Epoch 21/100
# 38/38 [==============================] - 5s 121ms/step - loss: 0.7327 - accuracy: 0.7146 - val_loss: 1.4880 - val_accuracy: 0.5185
# Epoch 22/100
# 38/38 [==============================] - 5s 124ms/step - loss: 0.7367 - accuracy: 0.7054 - val_loss: 1.5257 - val_accuracy: 0.5387
# Epoch 23/100
# 38/38 [==============================] - 5s 125ms/step - loss: 0.6725 - accuracy: 0.7332 - val_loss: 1.4462 - val_accuracy: 0.5118
# Epoch 24/100
# 38/38 [==============================] - 5s 123ms/step - loss: 0.6240 - accuracy: 0.7525 - val_loss: 1.5312 - val_accuracy: 0.5421
# Epoch 25/100
# 38/38 [==============================] - 5s 123ms/step - loss: 0.5519 - accuracy: 0.7803 - val_loss: 1.5859 - val_accuracy: 0.5387
# Epoch 26/100
# 38/38 [==============================] - 5s 125ms/step - loss: 0.4283 - accuracy: 0.8359 - val_loss: 1.9279 - val_accuracy: 0.4916
# Epoch 27/100
# 38/38 [==============================] - 5s 124ms/step - loss: 0.4401 - accuracy: 0.8342 - val_loss: 1.7460 - val_accuracy: 0.5724
# Epoch 28/100
# 38/38 [==============================] - 5s 124ms/step - loss: 0.3895 - accuracy: 0.8535 - val_loss: 1.8678 - val_accuracy: 0.5825
# Epoch 29/100
# 38/38 [==============================] - 5s 126ms/step - loss: 0.3362 - accuracy: 0.8678 - val_loss: 1.8678 - val_accuracy: 0.5455
# Epoch 30/100
# 38/38 [==============================] - 5s 124ms/step - loss: 0.3237 - accuracy: 0.8763 - val_loss: 1.9470 - val_accuracy: 0.5421
# Epoch 31/100
# 38/38 [==============================] - 5s 124ms/step - loss: 0.2603 - accuracy: 0.8948 - val_loss: 2.1262 - val_accuracy: 0.5455
# Epoch 32/100
# 38/38 [==============================] - 5s 126ms/step - loss: 0.1906 - accuracy: 0.9301 - val_loss: 2.2506 - val_accuracy: 0.5522
# Epoch 33/100
# 38/38 [==============================] - 5s 124ms/step - loss: 0.1607 - accuracy: 0.9419 - val_loss: 2.3308 - val_accuracy: 0.5387
# Epoch 34/100
# 38/38 [==============================] - 5s 124ms/step - loss: 0.1544 - accuracy: 0.9487 - val_loss: 2.3662 - val_accuracy: 0.5556
# Epoch 35/100
# 38/38 [==============================] - 5s 124ms/step - loss: 0.1300 - accuracy: 0.9579 - val_loss: 2.5397 - val_accuracy: 0.5623
# Epoch 36/100
# 38/38 [==============================] - 5s 123ms/step - loss: 0.1191 - accuracy: 0.9545 - val_loss: 2.5829 - val_accuracy: 0.5320
# Epoch 37/100
# 38/38 [==============================] - 5s 125ms/step - loss: 0.1930 - accuracy: 0.9394 - val_loss: 2.4776 - val_accuracy: 0.5522
# Epoch 38/100
# 38/38 [==============================] - 5s 124ms/step - loss: 0.1597 - accuracy: 0.9436 - val_loss: 2.5153 - val_accuracy: 0.5286
# Epoch 39/100
# 38/38 [==============================] - 5s 123ms/step - loss: 0.1125 - accuracy: 0.9646 - val_loss: 2.5693 - val_accuracy: 0.5758
# Epoch 40/100
# 38/38 [==============================] - 5s 127ms/step - loss: 0.0801 - accuracy: 0.9739 - val_loss: 2.8335 - val_accuracy: 0.5589
# Epoch 41/100
# 38/38 [==============================] - 5s 124ms/step - loss: 0.0634 - accuracy: 0.9764 - val_loss: 2.9441 - val_accuracy: 0.5556
# Epoch 42/100
# 38/38 [==============================] - 5s 122ms/step - loss: 0.0931 - accuracy: 0.9731 - val_loss: 2.8854 - val_accuracy: 0.5455
# Epoch 43/100
# 38/38 [==============================] - 5s 125ms/step - loss: 0.0791 - accuracy: 0.9764 - val_loss: 2.8157 - val_accuracy: 0.5455
# Epoch 44/100
# 38/38 [==============================] - 5s 124ms/step - loss: 0.0710 - accuracy: 0.9815 - val_loss: 2.9636 - val_accuracy: 0.5724
# Epoch 45/100
# 38/38 [==============================] - 5s 125ms/step - loss: 0.0658 - accuracy: 0.9832 - val_loss: 2.9511 - val_accuracy: 0.5455
# Epoch 46/100
# 38/38 [==============================] - 5s 126ms/step - loss: 0.0744 - accuracy: 0.9798 - val_loss: 3.0075 - val_accuracy: 0.5354
# Epoch 47/100
# 38/38 [==============================] - 5s 123ms/step - loss: 0.0707 - accuracy: 0.9756 - val_loss: 3.4362 - val_accuracy: 0.5286
# Epoch 48/100
# 38/38 [==============================] - 5s 123ms/step - loss: 0.0808 - accuracy: 0.9764 - val_loss: 2.9819 - val_accuracy: 0.5253
# Epoch 49/100
# 38/38 [==============================] - 5s 126ms/step - loss: 0.0655 - accuracy: 0.9790 - val_loss: 3.0011 - val_accuracy: 0.5286
# Epoch 50/100
# 38/38 [==============================] - 5s 124ms/step - loss: 0.0766 - accuracy: 0.9739 - val_loss: 2.8982 - val_accuracy: 0.5387
# Epoch 51/100
# 38/38 [==============================] - 5s 124ms/step - loss: 0.1221 - accuracy: 0.9571 - val_loss: 2.6833 - val_accuracy: 0.5488
# Epoch 52/100
# 38/38 [==============================] - 5s 126ms/step - loss: 0.0705 - accuracy: 0.9739 - val_loss: 2.8405 - val_accuracy: 0.5455
# Epoch 53/100
# 38/38 [==============================] - 5s 124ms/step - loss: 0.0588 - accuracy: 0.9832 - val_loss: 3.5478 - val_accuracy: 0.5118
# Epoch 54/100
# 38/38 [==============================] - 5s 123ms/step - loss: 0.0534 - accuracy: 0.9781 - val_loss: 3.0366 - val_accuracy: 0.5421
# Epoch 55/100
# 38/38 [==============================] - 5s 126ms/step - loss: 0.0751 - accuracy: 0.9747 - val_loss: 3.1220 - val_accuracy: 0.5387
# Epoch 56/100
# 38/38 [==============================] - 5s 123ms/step - loss: 0.0412 - accuracy: 0.9857 - val_loss: 3.3732 - val_accuracy: 0.5320
# Epoch 57/100
# 38/38 [==============================] - 5s 123ms/step - loss: 0.0682 - accuracy: 0.9747 - val_loss: 2.8370 - val_accuracy: 0.5623
# Epoch 58/100
# 38/38 [==============================] - 5s 125ms/step - loss: 0.0357 - accuracy: 0.9882 - val_loss: 3.3193 - val_accuracy: 0.5118
# Epoch 59/100
# 38/38 [==============================] - 5s 122ms/step - loss: 0.0762 - accuracy: 0.9747 - val_loss: 3.3068 - val_accuracy: 0.5522
# Epoch 60/100
# 38/38 [==============================] - 5s 124ms/step - loss: 0.0861 - accuracy: 0.9731 - val_loss: 3.1461 - val_accuracy: 0.5084
# Epoch 61/100
# 38/38 [==============================] - 5s 126ms/step - loss: 0.0420 - accuracy: 0.9848 - val_loss: 3.2667 - val_accuracy: 0.4983
# Epoch 62/100
# 38/38 [==============================] - 5s 124ms/step - loss: 0.0382 - accuracy: 0.9857 - val_loss: 3.5627 - val_accuracy: 0.5051
# Epoch 63/100
# 38/38 [==============================] - 5s 133ms/step - loss: 0.0957 - accuracy: 0.9781 - val_loss: 3.2304 - val_accuracy: 0.4916
# Epoch 64/100
# 38/38 [==============================] - 5s 124ms/step - loss: 0.0796 - accuracy: 0.9764 - val_loss: 2.7519 - val_accuracy: 0.5219
# Epoch 65/100
# 38/38 [==============================] - 5s 123ms/step - loss: 0.0552 - accuracy: 0.9815 - val_loss: 3.0154 - val_accuracy: 0.5286
# Epoch 66/100
# 38/38 [==============================] - 5s 125ms/step - loss: 0.0740 - accuracy: 0.9865 - val_loss: 2.9647 - val_accuracy: 0.5455
# Epoch 67/100
# 38/38 [==============================] - 5s 125ms/step - loss: 0.0477 - accuracy: 0.9823 - val_loss: 3.0349 - val_accuracy: 0.5051
# Epoch 68/100
# 38/38 [==============================] - 5s 124ms/step - loss: 0.0554 - accuracy: 0.9815 - val_loss: 2.9437 - val_accuracy: 0.5185
# Epoch 69/100
# 38/38 [==============================] - 5s 126ms/step - loss: 0.0534 - accuracy: 0.9798 - val_loss: 3.3853 - val_accuracy: 0.4983
# Epoch 70/100
# 38/38 [==============================] - 5s 124ms/step - loss: 0.0366 - accuracy: 0.9899 - val_loss: 2.9395 - val_accuracy: 0.5623
# Epoch 71/100
# 38/38 [==============================] - 5s 124ms/step - loss: 0.0263 - accuracy: 0.9899 - val_loss: 2.9441 - val_accuracy: 0.5387
# Epoch 72/100
# 38/38 [==============================] - 5s 126ms/step - loss: 0.0333 - accuracy: 0.9857 - val_loss: 3.3964 - val_accuracy: 0.4983
# Epoch 73/100
# 38/38 [==============================] - 5s 123ms/step - loss: 0.0214 - accuracy: 0.9933 - val_loss: 3.2290 - val_accuracy: 0.5354
# Epoch 74/100
# 38/38 [==============================] - 5s 123ms/step - loss: 0.0285 - accuracy: 0.9899 - val_loss: 3.2790 - val_accuracy: 0.5522
# Epoch 75/100
# 38/38 [==============================] - 5s 126ms/step - loss: 0.0312 - accuracy: 0.9874 - val_loss: 3.7866 - val_accuracy: 0.5017
# Epoch 76/100
# 38/38 [==============================] - 5s 123ms/step - loss: 0.0302 - accuracy: 0.9916 - val_loss: 3.4106 - val_accuracy: 0.5017
# Epoch 77/100
# 38/38 [==============================] - 5s 123ms/step - loss: 0.0120 - accuracy: 0.9966 - val_loss: 3.5647 - val_accuracy: 0.5219
# Epoch 78/100
# 38/38 [==============================] - 5s 127ms/step - loss: 0.0248 - accuracy: 0.9916 - val_loss: 3.6015 - val_accuracy: 0.5152
# Epoch 79/100
# 38/38 [==============================] - 5s 123ms/step - loss: 0.0490 - accuracy: 0.9823 - val_loss: 3.7120 - val_accuracy: 0.4882
# Epoch 80/100
# 38/38 [==============================] - 5s 124ms/step - loss: 0.0716 - accuracy: 0.9756 - val_loss: 3.2417 - val_accuracy: 0.5185
# Epoch 81/100
# 38/38 [==============================] - 5s 126ms/step - loss: 0.0507 - accuracy: 0.9806 - val_loss: 3.4380 - val_accuracy: 0.5455
# Epoch 82/100
# 38/38 [==============================] - 5s 125ms/step - loss: 0.0371 - accuracy: 0.9857 - val_loss: 3.1498 - val_accuracy: 0.5387
# Epoch 83/100
# 38/38 [==============================] - 5s 124ms/step - loss: 0.0263 - accuracy: 0.9933 - val_loss: 3.5096 - val_accuracy: 0.5118
# Epoch 84/100
# 38/38 [==============================] - 5s 126ms/step - loss: 0.0340 - accuracy: 0.9891 - val_loss: 3.5025 - val_accuracy: 0.4983
# Epoch 85/100
# 38/38 [==============================] - 5s 122ms/step - loss: 0.0486 - accuracy: 0.9857 - val_loss: 2.9445 - val_accuracy: 0.5522
# Epoch 86/100
# 38/38 [==============================] - 5s 124ms/step - loss: 0.0224 - accuracy: 0.9916 - val_loss: 3.3673 - val_accuracy: 0.5219
# Epoch 87/100
# 38/38 [==============================] - 5s 125ms/step - loss: 0.0169 - accuracy: 0.9924 - val_loss: 3.5060 - val_accuracy: 0.5286
# Epoch 88/100
# 38/38 [==============================] - 5s 123ms/step - loss: 0.0136 - accuracy: 0.9949 - val_loss: 3.5760 - val_accuracy: 0.5185
# Epoch 89/100
# 38/38 [==============================] - 5s 124ms/step - loss: 0.0223 - accuracy: 0.9924 - val_loss: 3.8147 - val_accuracy: 0.5084
# Epoch 90/100
# 38/38 [==============================] - 5s 124ms/step - loss: 0.0220 - accuracy: 0.9899 - val_loss: 3.7945 - val_accuracy: 0.5253
# Epoch 91/100
# 38/38 [==============================] - 5s 123ms/step - loss: 0.0189 - accuracy: 0.9907 - val_loss: 3.9675 - val_accuracy: 0.5017
# Epoch 92/100
# 38/38 [==============================] - 5s 125ms/step - loss: 0.0145 - accuracy: 0.9933 - val_loss: 4.0903 - val_accuracy: 0.5118
# Epoch 93/100
# 38/38 [==============================] - 5s 123ms/step - loss: 0.0130 - accuracy: 0.9958 - val_loss: 4.1574 - val_accuracy: 0.5488
# Epoch 94/100
# 38/38 [==============================] - 5s 123ms/step - loss: 0.0235 - accuracy: 0.9916 - val_loss: 3.7485 - val_accuracy: 0.5286
# Epoch 95/100
# 38/38 [==============================] - 5s 126ms/step - loss: 0.0419 - accuracy: 0.9874 - val_loss: 3.8370 - val_accuracy: 0.5522
# Epoch 96/100
# 38/38 [==============================] - 5s 123ms/step - loss: 0.0397 - accuracy: 0.9840 - val_loss: 3.7559 - val_accuracy: 0.5185
# Epoch 97/100
# 38/38 [==============================] - 5s 123ms/step - loss: 0.1726 - accuracy: 0.9520 - val_loss: 3.5464 - val_accuracy: 0.4815
# Epoch 98/100
# 38/38 [==============================] - 5s 126ms/step - loss: 0.0809 - accuracy: 0.9680 - val_loss: 3.2911 - val_accuracy: 0.5051
# Epoch 99/100
# 38/38 [==============================] - 5s 122ms/step - loss: 0.0410 - accuracy: 0.9840 - val_loss: 3.4343 - val_accuracy: 0.5286
# Epoch 100/100
# 38/38 [==============================] - 5s 122ms/step - loss: 0.0246 - accuracy: 0.9916 - val_loss: 3.3255 - val_accuracy: 0.5488

# %%
model.save('model.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
from matplotlib import pyplot as plt

# %%
# plot the training loss and accuracy
N = 100 #number of epochs
plt.style.use("ggplot")
plt.figure()
plt.plot(np.arange(0, N), history.history["loss"], label="train_loss")
plt.plot(np.arange(0, N), history.history["val_loss"], label="val_loss")
plt.plot(np.arange(0, N), history.history["accuracy"], label="train_acc")
plt.plot(np.arange(0, N), history.history["val_accuracy"], label="val_acc")
plt.title("Training Loss and Accuracy")
plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
plt.legend(loc="center right")
plt.savefig("CNN_Model")

# %%
vaL_loss, val_accuracy= model.evaluate(x_test, y_test, verbose=0)
print("test loss:", vaL_loss,'%')
print("test accuracy:", val_accuracy,"%")
# Out:
# test loss: 3.778728723526001 %
# test accuracy: 0.5090909004211426 %

# %%
X = 32

img_size = 256

img_single = x_test[X]
img_single = cv2.resize(img_single, (img_size, img_size))
img_single = (np.expand_dims(img_single, 0))
img_single = img_single.reshape(img_single.shape[0],256,256,1)

predictions_single = model.predict(img_single)
print('A.I predicts:',categories[np.argmax(predictions_single)])
print("Correct prediction for label",np.argmax(y_test[X]),'is',categories[np.argmax(y_test[X])])
plt.imshow(np.squeeze(img_single))
plt.grid(False)
plt.show()
# Out:
# 1/1 [==============================] - 0s 281ms/step
# A.I predicts: Mild
# Correct prediction for label 1 is Mild

# %%
from sklearn.metrics import confusion_matrix
from mlxtend.plotting import plot_confusion_matrix

test_labels = np.argmax(y_test, axis=1)
predictions = model.predict(x_test)
predictions = np.argmax(predictions, axis=-1)


cm  = confusion_matrix(test_labels, predictions)
plt.figure()
plot_confusion_matrix(cm,figsize=(12,8), hide_ticks=True,cmap=plt.cm.Blues)
plt.xticks(range(5), ['Normal','Doubtful','Mid','Moderate','Severe'], fontsize=16)
plt.yticks(range(5), ['Normal','Doubtful','Mid','Moderate','Severe'], fontsize=16)
plt.show()
# Out:
# 6/6 [==============================] - 0s 27ms/step
